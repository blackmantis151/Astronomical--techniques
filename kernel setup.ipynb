# %%
import sys
print(sys.executable)

import numpy, pandas, scipy, astropy
print("numpy:", numpy.__version__)
print("pandas:", pandas.__version__)
print("scipy:", scipy.__version__)
print("astropy:", astropy.__version__)
print("all good")
# Out:
# The kernel failed to start as the Python Environment '.venv (broken) (Python 3.14.2)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
